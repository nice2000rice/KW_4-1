# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone "https://github.com/nice2000rice/KW_4-1.git"
# GitHub에서 내 파일들을 그대로 복사해서 위 경로에 저장
# Out:
# Cloning into 'KW_4-1'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 1), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (7/7), done.
# Resolving deltas: 100% (1/1), done.

# %%
# !git init
#현재 경로에 Git 저장소를 생성
# !git config --global user.email "nice2000rice@gmail.com"
# !git config --global user.name "nice2000rice"
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/KW_4-1
# !git add .  #이 경로에 있는 모든 파일을 관리하기위해 등록
# !git commit -m "Edit Readme.md"
# Out:
#   File "<ipython-input-15-8edda4ebbc97>", line 1
#     cd /content/drive/MyDrive/Colab\ Notebooks/KW_4-1
#                                     ^
# SyntaxError: unexpected character after line continuation character
